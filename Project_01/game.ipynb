# %% [markdown]
# Игра угадай число

# %%
from game_v3 import random_predict
from game_v3 import count_attempts

# %% [markdown]
# Угадываем рандомно

# %%
count_attempts(random_predict)
# Out:
# Алгоритм рассчитал число 28 за 5 попыток
# Алгоритм рассчитал число 97 за 5 попыток
# Алгоритм рассчитал число 67 за 7 попыток
# Алгоритм рассчитал число 28 за 5 попыток
# Алгоритм рассчитал число 27 за 7 попыток
# Алгоритм рассчитал число 7 за 6 попыток
# Алгоритм рассчитал число 79 за 6 попыток
# Алгоритм рассчитал число 61 за 7 попыток
# Алгоритм рассчитал число 96 за 7 попыток
# Алгоритм рассчитал число 15 за 5 попыток
# Алгоритм рассчитал число 7 за 6 попыток
# Алгоритм рассчитал число 17 за 7 попыток
# Алгоритм рассчитал число 76 за 6 попыток
# Алгоритм рассчитал число 30 за 7 попыток
# Алгоритм рассчитал число 59 за 5 попыток
# Алгоритм рассчитал число 49 за 7 попыток
# Алгоритм рассчитал число 93 за 7 попыток
# Алгоритм рассчитал число 36 за 7 попыток
# Алгоритм рассчитал число 44 за 6 попыток
# Алгоритм рассчитал число 94 за 4 попыток
# Алгоритм рассчитал число 24 за 7 попыток
# Алгоритм рассчитал число 53 за 5 попыток
# Алгоритм рассчитал число 74 за 7 попыток
# ...
